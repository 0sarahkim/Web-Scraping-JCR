# %%
import pandas as pd
import csv

# %%
df = pd.read_csv ('jcr_journals2.csv')

# %%
df
# Out:
#                                                  Title  \
# 0    Why Are Donors More Generous with Time than Mo...
# 1    Experiential and Analytical Price Evaluations:...
# 2    Brand Morphogenesis: The Role of Heterogeneous...
# 3          Money, Sacrificial Work, and Poor Consumers
# 4    The Off by 100% Bias: The Effects of Percentag...
# ..                                                 ...
# 871  Consumer Reactions to Brand Extensions in a Co...
# 872  Still Preoccupied with 1995: The Need to Belon...
# 873  Street Art, Sweet Art? Reclaiming the “Public”...
# 874                           Forthcoming in June 2010
# 875          Broadening the Scope of Consumer Research
#
#                                               Abstract Published Date  \
# 0    Solicitation of time and money donations are c...       7-Mar-22
# 1    Quantity can be described using perceptual uni...       4-Mar-22
# 2    How do brands change in environments defined b...      28-Feb-22
# ...
